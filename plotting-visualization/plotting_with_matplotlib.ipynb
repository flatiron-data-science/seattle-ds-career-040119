# %% [markdown]
# # Data Visualization: Plotting with Matplotlib

# %% [markdown]
# ## Objectives
#
# 1. Configure a Jupyter Notebook for inline visualizations with `pyplot`
# 2. Create `fig` and `ax` objects with `plt.subplots()`
# 3. Add titles and axis labels to a plot.
# 4. Visualize data using a scatterplot.
# 5. Visualize sequential data using a line plot.
# 6. Visualize data using a bar chart.
# 7. Explain why data scientists don't use pie charts.
# 8. Use `pd.scatter_matrix()` for rapid data exploration.

# %% [markdown]
# ### 1. Configure Jupyter for inline visualizations with `pyplot`

# %%
import numpy as np
import pandas as pd
from scipy import stats
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 2. Create `fig` and `ax` objects with `plt.subplots()`

# %% [markdown]
# #### 2a. Creating a figure with _one_ set of axes

# %%
fig, ax = plt.subplots() # this assigns variables fig and ax to the tuple within the ()

# %%
# Apply a style
plt.style.use('ggplot')  # ggplot is the plotting library in R
fig, ax = plt.subplots()

# %%
pc = ax.scatter(0.5, 0.5)

# %%
pc.aname #I think this gave a random name
# Out:
# 'Artist'

# %%
fig

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %% [markdown]
# #### 2(b) Creating a figure with _multiple_ axes

# %%
fig, axs = plt.subplots(2, 2)

# %%
# Fix the ugliness
fig.tight_layout()
fig

# %%
# Referencing one set of axes
ax = axs[0][0]
ax.scatter(0.5, 0.5, color='blue')
fig

# %%
# This does the same thing, for the remaining axes
axs[0][1].scatter(0.5, 0.5, color='purple')
axs[1][0].scatter(0.5, 0.5, color='red')
axs[1][1].scatter(0.5, 0.5, color='green')

# %%
fig

# %% [markdown]
# ### 3. Add titles and axis labels to a plot

# %%
fig, ax = plt.subplots()

# %%
# Label the plot
ax.set_title('Data Science Learning')
fig

# %%
# Label your axes
ax.set_xlabel('Week')
ax.set_ylabel('Mastery (%)')
fig

# %%
# Set limits
ax.set_xlim(1, 15)
ax.set_ylim(0, 100)
fig

# %% [markdown]
# #### 4. Visualize data using a scatterplot.

# %%
fig, ax = plt.subplots()

# Label plot
ax.set_title('Interesting Data')

# Set limits
ax.set_xlim(0, 4)
ax.set_ylim(0, 4)

# Generate data
exponential_distribution = stats.expon()
x = exponential_distribution.rvs(10000)
y = exponential_distribution.rvs(10000)

# Plot
ax.scatter(x, y, color="purple")

# %% [markdown]
# ##### What's wrong with the plot above? How is it fixed below?

# %%
# Set figure size
fig, ax = plt.subplots(figsize=(5, 5))

# Label plot
ax.set_title('Interesting Data')

# # Set limits
# ax.set_xlim(0, 4)
# ax.set_ylim(0, 4)

# Generate data
exponential_distribution = stats.expon()
x = exponential_distribution.rvs(10000)
y = exponential_distribution.rvs(10000)

#Set limits that depend on the data
ax.set_xlim((x.min())*0.4, (x.max())*0.4)
ax.set_ylim(y.min(), y.max())

# Plot with alpha transparency
ax.scatter(x, y, alpha=.05, color="purple")

# %% [markdown]
# #### 5. Visualize sequential data using a line plot.

# %%
fig, ax = plt.subplots()

# Label plot
ax.set_title('Data Science Learning')

# Label axes
ax.set_xlabel('Week')
ax.set_ylabel('Mastery (%)')

# Set limits
ax.set_xlim(1, 15)
ax.set_ylim(0, 100)

x = np.arange(0, 16)
y = 40 + x**2/4

ax.plot(x, y, linestyle="dashed", color="green")

# %% [markdown]
# #### 6. Visualize data using a bar chart.

# %%
intros = pd.read_csv("/Users/humanperson/desktop/flatiron/go_fcode/codealongs/seattle-ds-career-040119/seattle_ds_intros.csv")

# %%
intros
# Out:
#     Unnamed: 0                   Name                  Student/Staff Birthday  \
# 0          NaN         David Fruchter                Campus Director      NaN
# 1          NaN           Rachel Young         Senior Program Manager      NaN
# 2          NaN              Alan Hong                Lead Instructor     5/17
# 3          NaN         Miles Erickson                Lead Instructor      NaN
# 4          NaN            Greg Damico                Lead Instructor     8/31
# 5          NaN          Kena Jalodora      Technical Coaching Fellow      NaN
# 6          NaN          Cristian Nuno      Technical Coaching Fellow      7/7
# 7          NaN           Katie Kavett  Campus Operations Coordinator     1/10
# 8          NaN                    NaN                            NaN      NaN
# 9          NaN                    NaN                            NaN      NaN
# 10         1.0  Laura E Shummon Maass                        Student     10/3
# 11         2.0           John Naujoks                        Student      NaN
# 12         3.0               Andy Luc                        Student     1/29
# 13         4.0          Lawrence Chew                        Student      4/4
# 14         5.0      Natasha Kacoroski                        Student      9/7
# 15         6.0            Jacob Crabb                        Student     5/20
# 16         7.0        Alex Shropshire                        Student     9/10
# 17         8.0            Kayli Leung                        Student     4/10
# 18         9.0            Sherry Yang                        Student     9/15
# 19        10.0             TaeHo Jeon                        Student    01/27
# 20        11.0        Connor Anderson                        Student     7/16
# 21        12.0           David Kaspar                        Student    12/19
# 22        13.0       Alexander Bailey                        Student     6/29
# 23        14.0         Patrick Fuller                        Student      NaN
# 24        15.0    Werlindo Mangrobang                        Student      5/9
# 25        16.0            Alec Morgan                        Student     9/15
# 26        17.0            Anna Zubova                        Student     5/13
# 27        18.0         Tara Greenwood                        Student    01/06
# 28        19.0          Mando Iwanaga                        Student    04/30
# 29        20.0             Lee Mackey                        Student     2/11
# 30        21.0          Hussein Sajid                        Student     10/3
#
#                               Email  \
# 0                               NaN
# 1                               NaN
# 2      alan.hong@flatironschool.com
# 3                               NaN
# 4    greg.damico@flatironschool.com
# 5                               NaN
# 6   cristian.nuno@flatironschoo.com
# 7   katie.kavett@flatironschool.com
# 8                               NaN
# 9                               NaN
# 10      laurashummonmaass@gmail.com
# 11            johnnaujoks@gmail.com
# 12               rokaandy@gmail.com
# 13             larrychewy@gmail.com
# 14             nkacoroski@gmail.com
# 15          alludedwinter@gmail.com
# 16                   as6140@nyu.edu
# 17           kay.schulz10@gmail.com
# 18          sherry.yang33@gmail.com
# 19              thjeon.wa@gmail.com
# 20      connorbanderson29@gmail.com
# 21               dakaspar@gmail.com
# 22             zbailey656@gmail.com
# 23         patrickbfuller@gmail.com
# 24    werlindo.mangrobang@gmail.com
# 25            AlecNMorgan@gmail.com
# 26                  anna@leolog.com
# 27           greenwood.ts@gmail.com
# 28         mandoiwanaga08@gmail.com
# 29                 glmack@gmail.com
# 30         hussein.sajid7@gmail.com
#
#                                             Short Bio  \
# 0                                                 NaN
# 1                                                 NaN
# 2   I joined Flatiron School in October 2018 as a ...
# 3                                                 NaN
# 4   I am new to Flatiron Seattle as of March 2019....
# 5                                                 NaN
# 6   I started at Flatiron on March 25, 2019 as a T...
# 7   I started at Flatiron in May 2017 as the Progr...
# 8                                                 NaN
# 9                                                 NaN
# 10  I moved to Seattle 4 years ago and have been w...
# 11  Hello all! For the past several years, I have ...
# 12  Hi! I graduated from ASU with a bachelors in s...
# 13                                                NaN
# 14  Greetings! If there's one thing to know about ...
# 15  I've got no fancy degrees or cool recomendatio...
# 16  Hi everyone! I'm Alex, a first time in Seattle...
# 17  Hello! I went to school at a small college bac...
# 18  Hey there! I’m excited to learn with you all t...
# 19  Hi! I'm Taeho from S.Korea. I moved to Seattle...
# 20  Hey everybody, I grew up in the Greater Seattl...
# 21  Hello to everyone! I'm also very excited to di...
# 22  Hello! I started out as a theater kid. Origina...
# 23  Hello! I have been working as a musician for t...
# 24  Hey all! I'm currently an Actuary by professio...
# 25  Hi all, I am an AI enthusiast with a strong pa...
# 26  Hi everyone! I was born in Russia, but I have ...
# 27  Hi team! I'm Tara (pronounced like guitar-a). ...
# 28  Hello everyone! I moved to WA about a year ago...
# 29  Hello! I recently moved to Seattle, and I'm ta...
# 30  Hello Everyone! I moved to WA about an year ag...
#
#                         Twitter  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6   https://twitter.com/cenuno_
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                   @sherzyang
# 19                    @teosoft7
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                          NaN
# 27                          NaN
# 28                          NaN
# 29                          NaN
# 30                          NaN
#
#                                             Facebook  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10            https://www.facebook.com/laura.maass.9
# 11             https://www.facebook.com/john.naujoks
# 12  https://www.facebook.com/profile.php?id=10039531
# 13                   https://www.facebook.com/lchewy
# 14        https://www.facebook.com/natasha.kacoroski
# 15            https://www.facebook.com/jacob.crabb.7
# 16               https://www.facebook.com/alex.shrop
# 17             https://www.facebook.com/kayli.schulz
# 18             https://www.facebook.com/sherry.yang3
# 19                 https://www.facebook.com/teo.jeon
# 20     https://www.facebook.com/connor.anderson.1428
# 21                                               NaN
# 22                                               NaN
# 23                    https://www.facebook.com/pfull
# 24                 https://www.facebook.com/werlindo
# 25                                               NaN
# 26           https://www.facebook.com/anna.lara.3705
# 27           https://www.facebook.com/tara.greenwood
# 28            https://www.facebook.com/mando.iwanaga
# 29                                               NaN
# 30            https://www.facebook.com/hussein.sajid
#
#                                              LinkedIn  \
# 0                                                 NaN
# 1                                                 NaN
# 2             https://www.linkedin.com/in/alanhong84/
# 3                                                 NaN
# 4             https://www.linkedin.com/in/greg-damico
# 5                                                 NaN
# 6            https://www.linkedin.com/in/cristiannuno
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10   https://www.linkedin.com/in/laura-shummon-maass/
# 11           https://www.linkedin.com/in/johnnaujoks/
# 12     https://www.linkedin.com/in/andy-luc-b30aa258/
# 13  https://www.linkedin.com/in/lawrence-chew-9958...
# 14      https://www.linkedin.com/in/natashakacoroski/
# 15  https://www.linkedin.com/in/jacob-crabb-971121...
# 16        https://www.linkedin.com/in/alexshropshire/
# 17                    www.linkedin.com/in/kaylischulz
# 18                      www.linkedin.com/in/sherzyang
# 19   https://www.linkedin.com/in/taeho-jeon-78418870/
# 20     https://www.linkedin.com/in/connor-anderson29/
# 21      https://www.linkedin.com/in/davidkasparworks/
# 22               www.linkedin.com/in/alexander-bailey
# 23  https://www.linkedin.com/in/patrick-fuller-287...
# 24              https://www.linkedin.com/in/werlindo/
# 25                                                NaN
# 26            https://www.linkedin.com/in/annazubova/
# 27        https://www.linkedin.com/in/tara-greenwood/
# 28  https://www.linkedin.com/in/mando-iwanaga-89b3...
# 29                     https://www.linkedin.com/feed/
# 30                                                NaN
#
#                                                GitHub  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  https://github.com/UpwardTrajectory?tab=reposi...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                                Where did you grow up?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                         Houston, TX
# 3                                                 NaN
# 4                                        Columbus, OH
# 5                                                 NaN
# 6                                         Chicago, IL
# 7                                          New Jersey
# 8                                                 NaN
# 9                                                 NaN
# 10                                      Milwaukee, WI
# 11                                      Cleveland, OH
# 12                                       Chandler, AZ
# 13                                    Foster City, CA
# 14                                       Kirkland, WA
# 15                                     Snoqualmie, Wa
# 16                                       La Verne, CA
# 17                                        Seattle, WA
# 18                                  Philadelphia, PA
# 19                                     Seoul, S.Korea
# 20                                    Federal Way, WA
# 21             Frankfort, IN (school mascot: Hotdogs)
# 22                              Bainbridge Island, WA
# 23                                      Pinehurst, NC
# 24                                      Bremerton, WA
# 25                               Washington and Idaho
# 26                              St.Petersburg, Russia
# 27  Various places in Alaska and a couple years in...
# 28                                               Guam
# 29                                       St. Paul, MN
# 30                                 Islamabad,Pakistan
#
#                      Where do you live now?
# 0                                       NaN
# 1                                       NaN
# 2                               Houston, TX
# 3                                       NaN
# 4                               Seattle, WA
# 5                                       NaN
# 6                               Seattle, WA
# 7                             New York City
# 8                                       NaN
# 9                                       NaN
# 10                              Seattle, WA
# 11                              Seattle, WA
# 12                        Mercer Island, WA
# 13                          Los Angeles, CA
# 14                               Renton, WA
# 15                            Snoqualmie,Wa
# 16                          Los Angeles, CA
# 17                              Seattle, WA
# 18  Los Angeles, CA (Seattle, WA for class)
# 19                           Mill Creek, WA
# 20                          Beacon Hill, WA
# 21                  Seattle (Phinney Ridge)
# 22                    Bainbridge Island, WA
# 23                              Seattle, WA
# 24                              Seattle, WA
# 25                              Seattle, WA
# 26                            Malaga, Spain
# 27                              Seattle, WA
# 28                          Bonney Lake, WA
# 29                              Seattle, WA
# 30                              Bellevue,WA

# %%
intros["Birthday"].value_counts()
# Out:
# 10/3     2
# 9/15     2
# 7/7      1
# 5/13     1
# 9/10     1
# 5/17     1
# 1/10     1
# 4/4      1
# 1/29     1
# 6/29     1
# 7/16     1
# 12/19    1
# 8/31     1
# 5/9      1
# 4/10     1
# 01/06    1
# 04/30    1
# 9/7      1
# 01/27    1
# 2/11     1
# 5/20     1
# Name: Birthday, dtype: int64

# %%
x = intros[intros["Birthday"] != 0]
x
# Out:
#     Unnamed: 0                   Name                  Student/Staff Birthday  \
# 0          NaN         David Fruchter                Campus Director      NaN
# 1          NaN           Rachel Young         Senior Program Manager      NaN
# 2          NaN              Alan Hong                Lead Instructor     5/17
# 3          NaN         Miles Erickson                Lead Instructor      NaN
# 4          NaN            Greg Damico                Lead Instructor     8/31
# 5          NaN          Kena Jalodora      Technical Coaching Fellow      NaN
# 6          NaN          Cristian Nuno      Technical Coaching Fellow      7/7
# 7          NaN           Katie Kavett  Campus Operations Coordinator     1/10
# 8          NaN                    NaN                            NaN      NaN
# 9          NaN                    NaN                            NaN      NaN
# 10         1.0  Laura E Shummon Maass                        Student     10/3
# 11         2.0           John Naujoks                        Student      NaN
# 12         3.0               Andy Luc                        Student     1/29
# 13         4.0          Lawrence Chew                        Student      4/4
# 14         5.0      Natasha Kacoroski                        Student      9/7
# 15         6.0            Jacob Crabb                        Student     5/20
# 16         7.0        Alex Shropshire                        Student     9/10
# 17         8.0            Kayli Leung                        Student     4/10
# 18         9.0            Sherry Yang                        Student     9/15
# 19        10.0             TaeHo Jeon                        Student    01/27
# 20        11.0        Connor Anderson                        Student     7/16
# 21        12.0           David Kaspar                        Student    12/19
# 22        13.0       Alexander Bailey                        Student     6/29
# 23        14.0         Patrick Fuller                        Student      NaN
# 24        15.0    Werlindo Mangrobang                        Student      5/9
# 25        16.0            Alec Morgan                        Student     9/15
# 26        17.0            Anna Zubova                        Student     5/13
# 27        18.0         Tara Greenwood                        Student    01/06
# 28        19.0          Mando Iwanaga                        Student    04/30
# 29        20.0             Lee Mackey                        Student     2/11
# 30        21.0          Hussein Sajid                        Student     10/3
#
#                               Email  \
# 0                               NaN
# 1                               NaN
# 2      alan.hong@flatironschool.com
# 3                               NaN
# 4    greg.damico@flatironschool.com
# 5                               NaN
# 6   cristian.nuno@flatironschoo.com
# 7   katie.kavett@flatironschool.com
# 8                               NaN
# 9                               NaN
# 10      laurashummonmaass@gmail.com
# 11            johnnaujoks@gmail.com
# 12               rokaandy@gmail.com
# 13             larrychewy@gmail.com
# 14             nkacoroski@gmail.com
# 15          alludedwinter@gmail.com
# 16                   as6140@nyu.edu
# 17           kay.schulz10@gmail.com
# 18          sherry.yang33@gmail.com
# 19              thjeon.wa@gmail.com
# 20      connorbanderson29@gmail.com
# 21               dakaspar@gmail.com
# 22             zbailey656@gmail.com
# 23         patrickbfuller@gmail.com
# 24    werlindo.mangrobang@gmail.com
# 25            AlecNMorgan@gmail.com
# 26                  anna@leolog.com
# 27           greenwood.ts@gmail.com
# 28         mandoiwanaga08@gmail.com
# 29                 glmack@gmail.com
# 30         hussein.sajid7@gmail.com
#
#                                             Short Bio  \
# 0                                                 NaN
# 1                                                 NaN
# 2   I joined Flatiron School in October 2018 as a ...
# 3                                                 NaN
# 4   I am new to Flatiron Seattle as of March 2019....
# 5                                                 NaN
# 6   I started at Flatiron on March 25, 2019 as a T...
# 7   I started at Flatiron in May 2017 as the Progr...
# 8                                                 NaN
# 9                                                 NaN
# 10  I moved to Seattle 4 years ago and have been w...
# 11  Hello all! For the past several years, I have ...
# 12  Hi! I graduated from ASU with a bachelors in s...
# 13                                                NaN
# 14  Greetings! If there's one thing to know about ...
# 15  I've got no fancy degrees or cool recomendatio...
# 16  Hi everyone! I'm Alex, a first time in Seattle...
# 17  Hello! I went to school at a small college bac...
# 18  Hey there! I’m excited to learn with you all t...
# 19  Hi! I'm Taeho from S.Korea. I moved to Seattle...
# 20  Hey everybody, I grew up in the Greater Seattl...
# 21  Hello to everyone! I'm also very excited to di...
# 22  Hello! I started out as a theater kid. Origina...
# 23  Hello! I have been working as a musician for t...
# 24  Hey all! I'm currently an Actuary by professio...
# 25  Hi all, I am an AI enthusiast with a strong pa...
# 26  Hi everyone! I was born in Russia, but I have ...
# 27  Hi team! I'm Tara (pronounced like guitar-a). ...
# 28  Hello everyone! I moved to WA about a year ago...
# 29  Hello! I recently moved to Seattle, and I'm ta...
# 30  Hello Everyone! I moved to WA about an year ag...
#
#                         Twitter  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6   https://twitter.com/cenuno_
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                   @sherzyang
# 19                    @teosoft7
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                          NaN
# 27                          NaN
# 28                          NaN
# 29                          NaN
# 30                          NaN
#
#                                             Facebook  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10            https://www.facebook.com/laura.maass.9
# 11             https://www.facebook.com/john.naujoks
# 12  https://www.facebook.com/profile.php?id=10039531
# 13                   https://www.facebook.com/lchewy
# 14        https://www.facebook.com/natasha.kacoroski
# 15            https://www.facebook.com/jacob.crabb.7
# 16               https://www.facebook.com/alex.shrop
# 17             https://www.facebook.com/kayli.schulz
# 18             https://www.facebook.com/sherry.yang3
# 19                 https://www.facebook.com/teo.jeon
# 20     https://www.facebook.com/connor.anderson.1428
# 21                                               NaN
# 22                                               NaN
# 23                    https://www.facebook.com/pfull
# 24                 https://www.facebook.com/werlindo
# 25                                               NaN
# 26           https://www.facebook.com/anna.lara.3705
# 27           https://www.facebook.com/tara.greenwood
# 28            https://www.facebook.com/mando.iwanaga
# 29                                               NaN
# 30            https://www.facebook.com/hussein.sajid
#
#                                              LinkedIn  \
# 0                                                 NaN
# 1                                                 NaN
# 2             https://www.linkedin.com/in/alanhong84/
# 3                                                 NaN
# 4             https://www.linkedin.com/in/greg-damico
# 5                                                 NaN
# 6            https://www.linkedin.com/in/cristiannuno
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10   https://www.linkedin.com/in/laura-shummon-maass/
# 11           https://www.linkedin.com/in/johnnaujoks/
# 12     https://www.linkedin.com/in/andy-luc-b30aa258/
# 13  https://www.linkedin.com/in/lawrence-chew-9958...
# 14      https://www.linkedin.com/in/natashakacoroski/
# 15  https://www.linkedin.com/in/jacob-crabb-971121...
# 16        https://www.linkedin.com/in/alexshropshire/
# 17                    www.linkedin.com/in/kaylischulz
# 18                      www.linkedin.com/in/sherzyang
# 19   https://www.linkedin.com/in/taeho-jeon-78418870/
# 20     https://www.linkedin.com/in/connor-anderson29/
# 21      https://www.linkedin.com/in/davidkasparworks/
# 22               www.linkedin.com/in/alexander-bailey
# 23  https://www.linkedin.com/in/patrick-fuller-287...
# 24              https://www.linkedin.com/in/werlindo/
# 25                                                NaN
# 26            https://www.linkedin.com/in/annazubova/
# 27        https://www.linkedin.com/in/tara-greenwood/
# 28  https://www.linkedin.com/in/mando-iwanaga-89b3...
# 29                     https://www.linkedin.com/feed/
# 30                                                NaN
#
#                                                GitHub  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  https://github.com/UpwardTrajectory?tab=reposi...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                                Where did you grow up?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                         Houston, TX
# 3                                                 NaN
# 4                                        Columbus, OH
# 5                                                 NaN
# 6                                         Chicago, IL
# 7                                          New Jersey
# 8                                                 NaN
# 9                                                 NaN
# 10                                      Milwaukee, WI
# 11                                      Cleveland, OH
# 12                                       Chandler, AZ
# 13                                    Foster City, CA
# 14                                       Kirkland, WA
# 15                                     Snoqualmie, Wa
# 16                                       La Verne, CA
# 17                                        Seattle, WA
# 18                                  Philadelphia, PA
# 19                                     Seoul, S.Korea
# 20                                    Federal Way, WA
# 21             Frankfort, IN (school mascot: Hotdogs)
# 22                              Bainbridge Island, WA
# 23                                      Pinehurst, NC
# 24                                      Bremerton, WA
# 25                               Washington and Idaho
# 26                              St.Petersburg, Russia
# 27  Various places in Alaska and a couple years in...
# 28                                               Guam
# 29                                       St. Paul, MN
# 30                                 Islamabad,Pakistan
#
#                      Where do you live now?
# 0                                       NaN
# 1                                       NaN
# 2                               Houston, TX
# 3                                       NaN
# 4                               Seattle, WA
# 5                                       NaN
# 6                               Seattle, WA
# 7                             New York City
# 8                                       NaN
# 9                                       NaN
# 10                              Seattle, WA
# 11                              Seattle, WA
# 12                        Mercer Island, WA
# 13                          Los Angeles, CA
# 14                               Renton, WA
# 15                            Snoqualmie,Wa
# 16                          Los Angeles, CA
# 17                              Seattle, WA
# 18  Los Angeles, CA (Seattle, WA for class)
# 19                           Mill Creek, WA
# 20                          Beacon Hill, WA
# 21                  Seattle (Phinney Ridge)
# 22                    Bainbridge Island, WA
# 23                              Seattle, WA
# 24                              Seattle, WA
# 25                              Seattle, WA
# 26                            Malaga, Spain
# 27                              Seattle, WA
# 28                          Bonney Lake, WA
# 29                              Seattle, WA
# 30                              Bellevue,WA

# %%
y = x["Birthday"].value_counts()
y
len(y)
# Out:
# 21

# %%
fig, ax = plt.subplots()
ax.set_title("Class birthday breakdown")

ax.set_xlabel("Birthday")
ax.set_ylabel("How many")

ax.bar(x,y, width = 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-061ffe128740> in <module>
#       5 ax.set_ylabel("How many")
#       6
# ----> 7 ax.bar(x,y, width = 2)
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2249         x, height, width, y, linewidth = np.broadcast_arrays(
#    2250             # Make args iterable too.
# -> 2251             np.atleast_1d(x), height, width, y, linewidth)
#    2252
#    2253         # Now that units have been converted, set the tick locations.
#
# /anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     250     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     251
# --> 252     shape = _broadcast_shape(*args)
#     253
#     254     if all(array.shape == shape for array in args):
#
# /anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     185     # use the old-iterator because np.nditer does not handle size 0 arrays
#     186     # consistently
# --> 187     b = np.broadcast(*args[:32])
#     188     # unfortunately, it cannot handle 32 or more arguments directly
#     189     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
# fig, ax = plt.subplots()

# # Label plot
# ax.set_title('Class birthdays')

# # Label axes
# ax.set_xlabel("Birthday")
# ax.set_ylabel("How many")




# ax.bar(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-e606a9bdd9ba> in <module>
#      11
#      12
# ---> 13 ax.bar(x, y)
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2249         x, height, width, y, linewidth = np.broadcast_arrays(
#    2250             # Make args iterable too.
# -> 2251             np.atleast_1d(x), height, width, y, linewidth)
#    2252
#    2253         # Now that units have been converted, set the tick locations.
#
# /anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     250     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     251
# --> 252     shape = _broadcast_shape(*args)
#     253
#     254     if all(array.shape == shape for array in args):
#
# /anaconda3/lib/python3.7/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     185     # use the old-iterator because np.nditer does not handle size 0 arrays
#     186     # consistently
# --> 187     b = np.broadcast(*args[:32])
#     188     # unfortunately, it cannot handle 32 or more arguments directly
#     189     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %% [markdown]
# #### 7. Explain why data scientists don't use pie charts.

# %% [markdown]
# #### 8. Use `pd.scatter_matrix()` for rapid data exploration.
